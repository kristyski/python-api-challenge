# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from config import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
filepath = "../output_data/weather.csv"

# %%
weather_file = pd.read_csv(filepath)
weather_file.head()
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0     East London    -33.02      27.91     71.78        27           0
# 1         Kahului     20.89    -156.47     77.00        69          40
# 2          Hobart    -42.88     147.33     48.00        75          40
# 3  Kulhudhuffushi      6.62      73.07     82.76        81         100
# 4        Thompson     55.74     -97.86     73.40        38          20
#
#    Wind Speed Country        Date
# 0        7.85      ZA  1596389458
# 1       16.11      US  1596389430
# 2        9.17      AU  1596389435
# 3       19.22      MV  1596389444
# 4        3.36      CA  1596389278

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
import gmaps.datasets

gmaps.configure(g_key) # Fill in with your API key

# %%
locations = weather_file[['Latitude', 'Longitude']]
weights = weather_file['Humidity']

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
vacation_df = pd.DataFrame(weather_file)
vacation_df.head()
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0     East London    -33.02      27.91     71.78        27           0
# 1         Kahului     20.89    -156.47     77.00        69          40
# 2          Hobart    -42.88     147.33     48.00        75          40
# 3  Kulhudhuffushi      6.62      73.07     82.76        81         100
# 4        Thompson     55.74     -97.86     73.40        38          20
#
#    Wind Speed Country        Date
# 0        7.85      ZA  1596389458
# 1       16.11      US  1596389430
# 2        9.17      AU  1596389435
# 3       19.22      MV  1596389444
# 4        3.36      CA  1596389278

# %%
ideal_vaca_df = vacation_df.loc[(vacation_df["Max Temp"] >= 25) & (vacation_df["Max Temp"] <= 60) & (vacation_df["Humidity"] <=60)]
ideal_vaca_df.count()
# Out:
# City          15
# Latitude      15
# Longitude     15
# Max Temp      15
# Humidity      15
# Cloudiness    15
# Wind Speed    15
# Country       14
# Date          15
# dtype: int64

# %%
ideal_vaca_df.head()
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 8        Tasiilaq     65.61     -37.64     53.60        37          18
# 83        Cradock    -32.16      25.62     59.50        27           0
# 93   Grootfontein    -19.57      18.12     54.32        36           0
# 152        Rawson    -43.30     -65.10     56.30        38          30
# 194      Ust-Nera     64.57     143.20     52.83        60          98
#
#      Wind Speed Country        Date
# 8         21.92      GL  1596389460
# 83         7.72      ZA  1596389482
# 93         6.04     NaN  1596389485
# 152       11.95      AR  1596389503
# 194        1.52      RU  1596389515

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_vaca_df

hotel_df["Hotel Name"] = ""

hotel_df.head()
# Out:
# C:\Users\krist\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 8        Tasiilaq     65.61     -37.64     53.60        37          18
# 83        Cradock    -32.16      25.62     59.50        27           0
# 93   Grootfontein    -19.57      18.12     54.32        36           0
# 152        Rawson    -43.30     -65.10     56.30        38          30
# 194      Ust-Nera     64.57     143.20     52.83        60          98
#
#      Wind Speed Country        Date Hotel Name
# 8         21.92      GL  1596389460
# 83         7.72      ZA  1596389482
# 93         6.04     NaN  1596389485
# 152       11.95      AR  1596389503
# 194        1.52      RU  1596389515

# %%
# in GooglePlaces

# set up a parameters dictionary
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Latitude"]
    lng = row["Longitude"]
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging", lat/lng and 5000 meter radius
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    name_address = requests.get(base_url, params=params)
    
    # convert to json
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name
        
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    
    except (KeyError, IndexError):
    
        print("Missing field/result... skipping.")
        
hotel_df
# Out:
# C:\Users\krist\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                    City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 8              Tasiilaq     65.61     -37.64     53.60        37          18
# 83              Cradock    -32.16      25.62     59.50        27           0
# 93         Grootfontein    -19.57      18.12     54.32        36           0
# 152              Rawson    -43.30     -65.10     56.30        38          30
# 194            Ust-Nera     64.57     143.20     52.83        60          98
# 259       Puerto Madryn    -42.77     -65.04     57.51        36          44
# 281           Bariloche    -41.15     -71.31     48.20        49          75
# 285           Mahalapye    -23.10      26.81     59.22        36           0
# 330            Ulaangom     49.98      92.07     58.42        55          35
# 341              Yulara    -25.24     130.99     42.80        22           0
# 401  Comodoro Rivadavia    -45.87     -67.50     57.20        44          46
# 459         Broken Hill    -31.95     141.43     48.20        36         100
# 488          Whitehorse     60.72    -135.05     59.00        58          75
# 493        Río Gallegos    -51.62     -69.22     42.80        60          11
# 537             Vryburg    -26.96      24.73     53.01        46           0
#
#      Wind Speed Country        Date                                Hotel Name
# 8         21.92      GL  1596389460                             The Red House
# 83         7.72      ZA  1596389482                              Die Hoekhuis
# 93         6.04     NaN  1596389485                         Meteor Travel Inn
# 152       11.95      AR  1596389503                          Hotel Punta León
# 194        1.52      RU  1596389515                            Hotel Ust-Nera
# 259        8.88      AR  1596389536                              Hotel Tolosa
# 281        9.17      AR  1596389532                           Hotel Patagonia
# 285        9.53      BW  1596389544                           Keeme-Nao Hotel
# 330        3.44      MN  1596389556             Achit Nuur Hotel & Restaurant
# 341        3.36      AU  1596389559  Desert Gardens Hotel - Ayers Rock Resort
# 401       17.22      AR  1596389401                             Austral Hotel
# 459        2.24      AU  1596389591                 Daydream Motel & Cottages
# 488       14.99      CA  1596389510                            Westmark Hotel
# 493       16.11      AR  1596389601                          Hotel Santa Cruz
# 537        4.27      ZA  1596389615                       Times Premier Lodge

# %%
# print the response url, avoid doing for public github repos in order to avoid exposing key
# print(response.url)

# %%
Plot markers on top of the heatmap.

# %%
# Print the json
print(json.dumps(name_address, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAAP1F0dvQ1NPaqAn9vSuoKkzDmagdxMWXUKkaiCsnv3KV9T5844kJD68bAb2uwpc_jG48N7LQRz2N11d89T_sMBbNnUY3XQZPJBQ8drZR15mPHvI_0ZLSgoZFnGoQ6uTTO-LsL7aIesEeJQhq5zod2AXGya6vKD9iW291YatVlr0ZzkXur6BiP_6YZ7PdX8APFfBkjS4G4XaruSst7ia9p4j9hCH7Qhh2vkK1t06Q1W1H0fcGXwSsXcI6zhvIlCCkIPTG4gRz7qbtffwycI6uWqLK8-nA_u6mmeAk8AbH4cZjTkOezCB4Bus98eIoO-wte09m8bV7xf14TPif4g5W9O5jkkIWfc7jAFyF22wig3rtJmnF-XXcDpIpn5m3FnQCDBIQJUUVM76F-TWizz3DKLx75BoUgIRVLUaFVHwNfcKk3smxT8SQOBI",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9607,
#                     "lng": 24.72949999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9593454697085,
#                         "lng": 24.7308067302915
#                     },
#                     "southwest": {
#                         "lat": -26.9620434302915,
#                         "lng": 24.72810876970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "fe1066176b1c4b350ecf088a1bbb2ecbca54a3a2",
#             "name": "Times Premier Lodge",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109961373371964504734\">Robert Terry</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARuYiIU-EygqZAZShe_rTXVqhiHO9uaTq1Vtl7YMVO-hfU168dycyr_Sfund1roGWv8V53u5lC3n5wTVNKLGDHre8ef_vhXqf3l_7kavsA1GOm6-P80gTDvdSO6lJpaRdEhAOmVD_PM2EsP5avCb2mdKnGhR1hJX25fkY2JWnlHRCHsjZhfgfHg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJGf6z07v6mB4RDzexyt0Dfaw",
#             "plus_code": {
#                 "compound_code": "2PQH+PR Vryburg, South Africa",
#                 "global_code": "5G562PQH+PR"
#             },
#             "rating": 3.3,
#             "reference": "ChIJGf6z07v6mB4RDzexyt0Dfaw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 35,
#             "vicinity": "Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9509037,
#                     "lng": 24.7230398
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9495870697085,
#                         "lng": 24.7243847802915
#                     },
#                     "southwest": {
#                         "lat": -26.9522850302915,
#                         "lng": 24.72168681970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bd0d63b7459124ac701fde05e744b6c332cf5285",
#             "name": "La Leo Luxury Guest House",
#             "photos": [
#                 {
#                     "height": 440,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110007226965966296601\">La Leo Luxury Guest House</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA7y8pIEeElczr46ZW__6wSqrfMQQaSttYOCMLnDMute9nezXhoEvpnFDDiI2QEZZqtn8jc3eIU_x9jZj4wP2ze091aAeq6ovk_Ig_W0Gkc0g-KkPrgaraOk9qgiG0GTLyEhCt6yCHjyWzwJxoXxdGihk_GhSregyHOgwzFLjoYU_7vKn1CKAZrA",
#                     "width": 625
#                 }
#             ],
#             "place_id": "ChIJeQrAKK_6mB4RxFNsxRhb4_8",
#             "plus_code": {
#                 "compound_code": "2PXF+J6 Vryburg, South Africa",
#                 "global_code": "5G562PXF+J6"
#             },
#             "rating": 4.6,
#             "reference": "ChIJeQrAKK_6mB4RxFNsxRhb4_8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "Corner Molopo Road, Fincham Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.946661,
#                     "lng": 24.72001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9452706197085,
#                         "lng": 24.7214232802915
#                     },
#                     "southwest": {
#                         "lat": -26.9479685802915,
#                         "lng": 24.7187253197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "DeHoek Guesthouse Vryburg",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114837541285105403361\">DeHoek Guesthouse Vryburg</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5Ij-yrGkxWTg6PCuJ4R0DY8e-Y6h4vIeAkqFfPRUyimVtapCzuY3zWEk0jU7SSNQ5Df4HDweqUPYPZi5yvq883wZ-W_Dn7Sc0kHgLAbtginqAcixv9ZXDguXZdEvW0UaEhBYIuK1pQ3JnIC_vUmIEOz3GhREZXgxgXAUcJpyL4aiWuRzab7_OQ",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJFQLTHar6mB4R-XdK4utL4yM",
#             "plus_code": {
#                 "compound_code": "3P3C+82 Vryburg, South Africa",
#                 "global_code": "5G563P3C+82"
#             },
#             "rating": 4.4,
#             "reference": "ChIJFQLTHar6mB4R-XdK4utL4yM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 46,
#             "vicinity": "5 Naas Raubenheimer Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9478173,
#                     "lng": 24.715075
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9464520197085,
#                         "lng": 24.7162841302915
#                     },
#                     "southwest": {
#                         "lat": -26.9491499802915,
#                         "lng": 24.7135861697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d1b8d190fefbaf9f8328d125ccc77c83d9b56513",
#             "name": "Vryburg - MAG MAR Guest house ****",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 810,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101392606912971172470\">Guest house Vryburg - MAG MAR Guest house ****</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIOovZVJTWgXhg1ZuyPaCnwVAFXPnmnqx56Rh-36Gg6f2kEd-_7DCpJdGIE7ccmHNIwdx0fvKwH33c3t9cFof3aOn-f1izQurrPxR8hw3nRxgidKOEpqU82d1WfeHDrf8EhBBkW4Vc0RkE74GkaY6DBmUGhQFGguXU1e_iE8Dc9Wwc4sTuPktPQ",
#                     "width": 1440
#                 }
#             ],
#             "place_id": "ChIJqc7NqKr6mB4RdXRA2B8a1XY",
#             "plus_code": {
#                 "compound_code": "3P28+V2 Vryburg, South Africa",
#                 "global_code": "5G563P28+V2"
#             },
#             "rating": 4.3,
#             "reference": "ChIJqc7NqKr6mB4RdXRA2B8a1XY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 57,
#             "vicinity": "27 Springbok Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.961,
#                     "lng": 24.7216
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.95965096970849,
#                         "lng": 24.7229860302915
#                     },
#                     "southwest": {
#                         "lat": -26.9623489302915,
#                         "lng": 24.72028806970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Lavender Lodge",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115953121126315847805\">Andrew Nel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAoLuNsQ7gRDqSJJHu-H-JzY9pVsyjD2EZvgVQp83_OnLLcbLfVSKPzxLP8iUWiIHAcRwfDBBacKEniLuZvVhesRa0zgPhsU4t7uFS8adSa_rFekdPgIv8G9NrOMyIgdLzEhCXmyFUdPc2wWUfWOKhs3CWGhRIeO5EivggSMB40Cv8cz48xJEJIQ",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJs0ENMK76mB4RIjO6MLcbTu4",
#             "plus_code": {
#                 "compound_code": "2PQC+JJ Vryburg, South Africa",
#                 "global_code": "5G562PQC+JJ"
#             },
#             "rating": 4.6,
#             "reference": "ChIJs0ENMK76mB4RIjO6MLcbTu4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 167,
#             "vicinity": "Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9556209,
#                     "lng": 24.7378955
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9543164197085,
#                         "lng": 24.7392373302915
#                     },
#                     "southwest": {
#                         "lat": -26.9570143802915,
#                         "lng": 24.7365393697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Chep",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ2VwHfb36mB4Rmx-CD97ucJM",
#             "plus_code": {
#                 "compound_code": "2PVQ+Q5 Vryburg, South Africa",
#                 "global_code": "5G562PVQ+Q5"
#             },
#             "rating": 4,
#             "reference": "ChIJ2VwHfb36mB4Rmx-CD97ucJM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12,
#             "vicinity": "McKenzie Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9610029,
#                     "lng": 24.7206788
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9597021197085,
#                         "lng": 24.7220196302915
#                     },
#                     "southwest": {
#                         "lat": -26.9624000802915,
#                         "lng": 24.7193216697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e315fff6de97cb55bbc76cc086775f5cdb324b89",
#             "name": "Ikanyeng Guest House",
#             "place_id": "ChIJlRF9Crn6mB4RxneieREL0CY",
#             "plus_code": {
#                 "compound_code": "2PQC+H7 Vryburg, South Africa",
#                 "global_code": "5G562PQC+H7"
#             },
#             "rating": 4,
#             "reference": "ChIJlRF9Crn6mB4RxneieREL0CY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "1 Voortrekker Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9591978,
#                     "lng": 24.7187585
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9577038197085,
#                         "lng": 24.72013228029151
#                     },
#                     "southwest": {
#                         "lat": -26.9604017802915,
#                         "lng": 24.7174343197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d0006cc940fda273920859b0fb96ee0c829eeaee",
#             "name": "Cosy Corner Accommodation",
#             "place_id": "ChIJF9DYYbn6mB4RHhAtRzOd4Q8",
#             "plus_code": {
#                 "compound_code": "2PR9+8G Vryburg, South Africa",
#                 "global_code": "5G562PR9+8G"
#             },
#             "rating": 4.6,
#             "reference": "ChIJF9DYYbn6mB4RHhAtRzOd4Q8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "11 Vry Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9514244,
#                     "lng": 24.7200356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9500925697085,
#                         "lng": 24.7213816802915
#                     },
#                     "southwest": {
#                         "lat": -26.9527905302915,
#                         "lng": 24.7186837197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Abella Guest House",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116990737234928572551\">sister squad</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdCc2cGR1Zkp0wYFjSwUX3jucogfpmKdvEnQg00ATFoHYmE99E6fMfYg4p8TXAC0Wuv4yNN8BKNzoU3LA9gbSC9OuVn9B2h4jUopEGFQZavyGpo4Dhv1fTy4IJkM5ycyIEhA_ZRVgy2B2jofO8PdGHuvXGhS9AtxmouPZOfg--WsDshMzNJTRAA",
#                     "width": 3096
#                 }
#             ],
#             "place_id": "ChIJgyCwxa76mB4RocKitK8nqAk",
#             "plus_code": {
#                 "compound_code": "2PXC+C2 Vryburg, South Africa",
#                 "global_code": "5G562PXC+C2"
#             },
#             "rating": 4.6,
#             "reference": "ChIJgyCwxa76mB4RocKitK8nqAk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 93,
#             "vicinity": "Jan Cilliers Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9542409,
#                     "lng": 24.7429518
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9529074197085,
#                         "lng": 24.7444261302915
#                     },
#                     "southwest": {
#                         "lat": -26.9556053802915,
#                         "lng": 24.74172816970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Dalavinics Guest House",
#             "photos": [
#                 {
#                     "height": 512,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110619391275725906217\">Leon Charl Ferris</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaXmrmF6ZTjcrMvkWwd1HTfKL-hKZG9AORmlddqYFM4xWUhP-NNUQxpm82dkwGWeod44Shv4ehiagrwMQeiCnPk6i4VJSgcGjPGWZnIDWF97hHTSQOPYcpy_0pywGL5uiEhBDv2v_0DD5UofViDU7kvQ1GhQ5-0xw4U64VEJT1bm0QiirVxwM1Q",
#                     "width": 912
#                 }
#             ],
#             "place_id": "ChIJyW21O5f6mB4RZVDvHP2EPcI",
#             "plus_code": {
#                 "compound_code": "2PWV+85 Vryburg, South Africa",
#                 "global_code": "5G562PWV+85"
#             },
#             "rating": 4.1,
#             "reference": "ChIJyW21O5f6mB4RZVDvHP2EPcI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 17,
#             "vicinity": "50 Royden Road, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.948474,
#                     "lng": 24.721779
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9471497697085,
#                         "lng": 24.7230902302915
#                     },
#                     "southwest": {
#                         "lat": -26.9498477302915,
#                         "lng": 24.7203922697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Molopo Travel Inn Vryburg",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 633,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115951335355391016134\">Molopo Travel Inn Vryburg</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIqVQ92waYWjL45_HNnikI8V-6RiO01RAiSL4YXyHSTVw3J3sjRv5t1azlc_KeCTbDtCkQLgqzDZuZBEDhysWQGgwXRxQSWIdF9fRXzXMljM6FScMbjxVMqKctq2RBYppEhAidKvTcYX8xs_wssCxhEncGhQcLN7-fFZ0vqMOojJ6IH-btXd39A",
#                     "width": 950
#                 }
#             ],
#             "place_id": "ChIJ40E6jKn6mB4RJ3suaBsiOKg",
#             "plus_code": {
#                 "compound_code": "3P2C+JP Vryburg, South Africa",
#                 "global_code": "5G563P2C+JP"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ40E6jKn6mB4RJ3suaBsiOKg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 104,
#             "vicinity": "28 Naas Raubenheimer Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9537507,
#                     "lng": 24.7136053
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9524169197085,
#                         "lng": 24.7150742302915
#                     },
#                     "southwest": {
#                         "lat": -26.9551148802915,
#                         "lng": 24.71237626970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Peace Haven Guest House",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111177268416341003704\">Peace Haven Guest House</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbNLB2eU9N1YmBnoCLxyFVauolx-oXBqjsvf0Y0Ghxqw2sjplSHdlP-TY-rLR2zwHRuWCms47keDvKpSQ6yXzn6Hs_4zOQ8bg9gFg8YfZmW6d9rWfM7OXg47u2nPTaU4WEhBGyarcMfMilXXPbdAPhIyQGhTLAvgs9jwE7ojFW_hAN1kWI2LAqg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ4cKmTlPlmB4Rq49ip2KiLWY",
#             "plus_code": {
#                 "compound_code": "2PW7+FC Vryburg, South Africa",
#                 "global_code": "5G562PW7+FC"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ4cKmTlPlmB4Rq49ip2KiLWY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 16,
#             "vicinity": "14 Koedoe Drive, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.946015,
#                     "lng": 24.71914
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9446361197085,
#                         "lng": 24.7204644802915
#                     },
#                     "southwest": {
#                         "lat": -26.9473340802915,
#                         "lng": 24.7177665197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "65657779c3e3f16b5e88d9e0b550b736a4183af4",
#             "name": "Tuscany",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2664,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118380309092202268799\">Tuscany</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAheP9P4KIa1WmXvZ51xVSIbVDOnvBL6TjVfFflDZjmoc-C09AOZ35vPKSOlYbcpRKLJjYwjImFxYyjcNe4dKDK2ZDrIdtQ4RGTiVyAAiZV8SEMk4KMm3Wg_3CaDs93tfFEhDo85j6NdlRSD50GUmm8mvSGhQMrcLziWg3obAcgHSZ9WVIyyxLzA",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJW4vzCar6mB4RH8Om8GiA2zQ",
#             "plus_code": {
#                 "compound_code": "3P39+HM Vryburg, South Africa",
#                 "global_code": "5G563P39+HM"
#             },
#             "rating": 3.9,
#             "reference": "ChIJW4vzCar6mB4RH8Om8GiA2zQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 43,
#             "vicinity": "15 Brown Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9496429,
#                     "lng": 24.7121911
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9482624697085,
#                         "lng": 24.7136734302915
#                     },
#                     "southwest": {
#                         "lat": -26.9509604302915,
#                         "lng": 24.7109754697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Game View Lodge",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104271956533037018596\">Les Turvey</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAeqd-jLdtmGRFF8I622D_Ewpy8klrnj0Chw5saEAJu-bDtpVJWJsDz11iKvL0-Y0HFtKdc2ZARyxpGc--5naLIXJ1goQMTFzKWVzAPehlPKWi4D3Gpzq3TktO9ygTxAhEhC-rHv7897Im7QckaCS-56OGhTy8OrGzydeQOzSuYReU3DxmR97SA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJm2ZiG1XlmB4Roc0U30J9olU",
#             "plus_code": {
#                 "compound_code": "3P26+4V Vryburg, South Africa",
#                 "global_code": "5G563P26+4V"
#             },
#             "rating": 4.7,
#             "reference": "ChIJm2ZiG1XlmB4Roc0U30J9olU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 211,
#             "vicinity": "32 Sable Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.95477469999999,
#                     "lng": 24.7251454
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.95343036970849,
#                         "lng": 24.7265321802915
#                     },
#                     "southwest": {
#                         "lat": -26.9561283302915,
#                         "lng": 24.7238342197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Twiggies Guest House",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107468018756945790815\">Twiggies Guest House</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5PSg45NoJDbTSLu2Q2XcB8yto66p3Rq85SyDAtKVIrsfNkmPN7rJBKiPzClLW46xymw0-4r1w6zS9TOpljFAV4A7s4KYIJ4WDtE9-ph_iuKaQQzoZG5JLgmLBWdFRnxkEhBVG3gIow0z0oIBAyN8mDtKGhQ-bNF65wgrf66hywnelGgqvzVE9A",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJOTEKHrD6mB4RnoyEQR_z4Hg",
#             "plus_code": {
#                 "compound_code": "2PWG+33 Vryburg, South Africa",
#                 "global_code": "5G562PWG+33"
#             },
#             "rating": 4.1,
#             "reference": "ChIJOTEKHrD6mB4RnoyEQR_z4Hg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 40,
#             "vicinity": "46 Van Niekerk Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9800313,
#                     "lng": 24.68781
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9786050197085,
#                         "lng": 24.6891312302915
#                     },
#                     "southwest": {
#                         "lat": -26.9813029802915,
#                         "lng": 24.68643326970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0d911852a6eeb979d2b9218d86041a354934005a",
#             "name": "Klondike Lodge",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2976,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103244014010601825752\">Phillip Coetzee</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAY8UAma79wGSRDPB61loAAN1XNQbJLP7LQP8k11me5fEBdxaGcfGsK6-ia-uHMXVXOIiZg83WMMlqBdlfNH6AjfFTSPD9IMNEcUTQ8qDPXxmLYVcspvFxlIPX5mLpgkcWEhAsyKnV2K7sNuCX3YcAC9VNGhR2KYDEJtJtRT9STHcezhDMxNR3IQ",
#                     "width": 3968
#                 }
#             ],
#             "place_id": "ChIJU9a6ZRblmB4RjeS_eWSlZug",
#             "plus_code": {
#                 "compound_code": "2M9Q+X4 Vryburg, South Africa",
#                 "global_code": "5G562M9Q+X4"
#             },
#             "rating": 3.9,
#             "reference": "ChIJU9a6ZRblmB4RjeS_eWSlZug",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 101,
#             "vicinity": "N14, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9572859,
#                     "lng": 24.71796089999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.95573741970849,
#                         "lng": 24.7193451302915
#                     },
#                     "southwest": {
#                         "lat": -26.9584353802915,
#                         "lng": 24.71664716970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Villa Brocant Guesthouse",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1196,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114429281337135694520\">Villa Brocant Guesthouse</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAiN54usRmU0-lpXfTsPtUN4ypMwIH1yDgH-aFuc_R_RUKWiKW8UCF9xRM64H_PGZ52zpG9N6A-Fn1O7s2u9-iaFVTRFsgqJ54tQh5Hq7lLAiYRWjzJ05ssvdopK_dhwGwEhBU3Y0-QXWS3mIQFgvZ2paPGhTti5htxMmzdc1Y8ycuvC0e4-JEWQ",
#                     "width": 1800
#                 }
#             ],
#             "place_id": "ChIJn6EDiK36mB4R1pTwzmohUCE",
#             "plus_code": {
#                 "compound_code": "2PV9+35 Vryburg, South Africa",
#                 "global_code": "5G562PV9+35"
#             },
#             "rating": 4.3,
#             "reference": "ChIJn6EDiK36mB4R1pTwzmohUCE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "furniture_store",
#                 "home_goods_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 183,
#             "vicinity": "1 Market Street, Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9584048,
#                     "lng": 24.7298615
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9570790697085,
#                         "lng": 24.7312070802915
#                     },
#                     "southwest": {
#                         "lat": -26.9597770302915,
#                         "lng": 24.7285091197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0474fc7b59058b3e63b27306cfe524313a830c1f",
#             "name": "Mack's Ptroleum",
#             "place_id": "ChIJkz7OFyP7mB4RtJYBwGfVL0w",
#             "plus_code": {
#                 "compound_code": "2PRH+JW Vryburg, South Africa",
#                 "global_code": "5G562PRH+JW"
#             },
#             "reference": "ChIJkz7OFyP7mB4RtJYBwGfVL0w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9601,
#                     "lng": 24.7277
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.9587505197085,
#                         "lng": 24.7290490802915
#                     },
#                     "southwest": {
#                         "lat": -26.9614484802915,
#                         "lng": 24.7263511197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "name": "Ngulube Lodge",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107482373477969830422\">Gerhard Booysen</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAiNpztKEG_NoIXirG3vu611SDag7PD6P1nPAHna__TGIislkGm2wmu4Im9t9JMVDxPxxmC16f3EYB03XDhFrB2V5sCS1AmmjPAYdS6xaFLLnwsL-jAIC_q3uwktzC4eWQEhDpv4P3Gn1NqKvwQzS1FT2jGhTLcRjEyTIGA-SZkPJ2YOABnKNhVw",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJg8_YYbn6mB4R1rDa-IMhhlM",
#             "plus_code": {
#                 "compound_code": "2PQH+X3 Vryburg, South Africa",
#                 "global_code": "5G562PQH+X3"
#             },
#             "rating": 3.4,
#             "reference": "ChIJg8_YYbn6mB4R1rDa-IMhhlM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 51,
#             "vicinity": "Vryburg"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -26.9616001,
#                     "lng": 24.7269866
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -26.96023331970849,
#                         "lng": 24.7281947802915
#                     },
#                     "southwest": {
#                         "lat": -26.9629312802915,
#                         "lng": 24.7254968197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a6bb1b3228db69bb3fbf3427138ee36b2cb005e9",
#             "name": "Olives Place Guesthouse",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJcZkQ-7n6mB4RoQn530L-0UU",
#             "plus_code": {
#                 "compound_code": "2PQG+9Q Vryburg, South Africa",
#                 "global_code": "5G562PQG+9Q"
#             },
#             "rating": 4.3,
#             "reference": "ChIJcZkQ-7n6mB4RoQn530L-0UU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "1 De Kock Street, Vryburg"
#         }
#     ],
#     "status": "OK"
# }

# %%
marker_locations = hotel_df[["Latitude", "Longitude"]]
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
#?
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
